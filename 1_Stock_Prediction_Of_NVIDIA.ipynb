# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import seaborn as sns
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading_The_Data_Set

# %%
df = pd.read_csv('1_NVDA.csv')

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-05-23    37.422501    37.422501    36.227501    36.830002
# 1     2019-05-24    37.020000    37.375000    36.220001    36.287498
# 2     2019-05-28    36.465000    36.794998    35.812500    35.832500
# 3     2019-05-29    35.352501    35.705002    34.735001    35.084999
# 4     2019-05-30    35.077499    35.437500    34.392502    34.777500
# ...          ...          ...          ...          ...          ...
# 1255  2024-05-17   943.690002   947.400024   918.059998   924.789978
# 1256  2024-05-20   937.500000   952.000000   934.400024   947.799988
# 1257  2024-05-21   935.989990   954.000000   931.799988   953.859985
# 1258  2024-05-22   954.590027   960.200012   932.489990   949.500000
# 1259  2024-05-23  1020.000000  1063.199951  1015.200012  1058.918579
#
#         Adj Close    Volume
# 0       36.579872  59184400
# 1       36.041054  35758400
# 2       35.589134  42835600
# 3       34.846722  55980000
# 4       34.580738  39430000
# ...           ...       ...
# 1255   924.789978  35969100
# 1256   947.799988  31876400
# 1257   953.859985  32894600
# 1258   949.500000  53725900
# 1259  1058.918579  53658481
#
# [1260 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean    236.259629   240.632726   231.748678   236.457376   236.246529
# std     203.974380   207.537564   200.074702   204.085654   204.154064
# min      33.977501    34.367500    33.150002    33.445000    33.255783
# 25%     116.956251   121.027501   114.323750   116.508123   116.403095
# 50%     168.160004   171.879997   164.275002   169.110001   169.027069
# 75%     277.930008   283.807510   272.702507   278.057495   277.813087
# max    1020.000000  1063.199951  1015.200012  1058.918579  1058.918579
#
#              Volume
# count  1.260000e+03
# mean   4.549841e+07
# std    1.842901e+07
# min    9.788400e+06
# 25%    3.235795e+07
# 50%    4.278820e+07
# 75%    5.514575e+07
# max    1.543911e+08

# %% [markdown]
# # Graph_Plot_Of_Stock_Prices

# %%
ax = df[['Date', 'Close']].groupby('Date').mean().plot(figsize=(10,6))
plt.ylabel('Closing Value')
plt.title('Closing Stock Price')
# Out:
# Text(0.5, 1.0, 'Closing Stock Price')

# %% [markdown]
# # Data_Mining

# %%
df['Tomorrow'] = df['Close'].shift(-1)
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-05-23    37.422501    37.422501    36.227501    36.830002
# 1     2019-05-24    37.020000    37.375000    36.220001    36.287498
# 2     2019-05-28    36.465000    36.794998    35.812500    35.832500
# 3     2019-05-29    35.352501    35.705002    34.735001    35.084999
# 4     2019-05-30    35.077499    35.437500    34.392502    34.777500
# ...          ...          ...          ...          ...          ...
# 1255  2024-05-17   943.690002   947.400024   918.059998   924.789978
# 1256  2024-05-20   937.500000   952.000000   934.400024   947.799988
# 1257  2024-05-21   935.989990   954.000000   931.799988   953.859985
# 1258  2024-05-22   954.590027   960.200012   932.489990   949.500000
# 1259  2024-05-23  1020.000000  1063.199951  1015.200012  1058.918579
#
#         Adj Close    Volume     Tomorrow
# 0       36.579872  59184400    36.287498
# 1       36.041054  35758400    35.832500
# 2       35.589134  42835600    35.084999
# 3       34.846722  55980000    34.777500
# 4       34.580738  39430000    33.865002
# ...           ...       ...          ...
# 1255   924.789978  35969100   947.799988
# 1256   947.799988  31876400   953.859985
# 1257   953.859985  32894600   949.500000
# 1258   949.500000  53725900  1058.918579
# 1259  1058.918579  53658481          NaN
#
# [1260 rows x 8 columns]

# %%
df['Target'] = (df['Tomorrow']>df['Close']).astype(int)
df1 = df.dropna()
df1
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2019-05-23   37.422501   37.422501   36.227501   36.830002   36.579872
# 1     2019-05-24   37.020000   37.375000   36.220001   36.287498   36.041054
# 2     2019-05-28   36.465000   36.794998   35.812500   35.832500   35.589134
# 3     2019-05-29   35.352501   35.705002   34.735001   35.084999   34.846722
# 4     2019-05-30   35.077499   35.437500   34.392502   34.777500   34.580738
# ...          ...         ...         ...         ...         ...         ...
# 1254  2024-05-16  949.099976  958.190002  941.030029  943.590027  943.590027
# 1255  2024-05-17  943.690002  947.400024  918.059998  924.789978  924.789978
# 1256  2024-05-20  937.500000  952.000000  934.400024  947.799988  947.799988
# 1257  2024-05-21  935.989990  954.000000  931.799988  953.859985  953.859985
# 1258  2024-05-22  954.590027  960.200012  932.489990  949.500000  949.500000
#
#         Volume     Tomorrow  Target
# 0     59184400    36.287498       0
# 1     35758400    35.832500       0
# 2     42835600    35.084999       0
# 3     55980000    34.777500       0
# 4     39430000    33.865002       0
# ...        ...          ...     ...
# 1254  32395200   924.789978       0
# 1255  35969100   947.799988       1
# 1256  31876400   953.859985       1
# 1257  32894600   949.500000       0
# 1258  53725900  1058.918579       1
#
# [1259 rows x 9 columns]

# %%
df1['Target'].value_counts()/df.shape[0]
# Out:
# 1    0.547619
# 0    0.451587
# Name: Target, dtype: float64

# %% [markdown]
# # Predicting_The_Growth_Of Next_Day

# %%
x = df1[['High', "Low", "Close", 'Open']]
y = df1['Target']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)

# %%
params = {'n_neighbors' : np.arange(1,21)}
knn = KNeighborsClassifier()
scores = []
cv_param = np.arange(2,20)
for cv_params in cv_param:
    knc = GridSearchCV(knn, params, cv=KFold(cv_params))
    knc.fit(x_train, y_train)
    score_knn = knc.score(x_test,y_test)
    scores.append(score_knn)
best_score_knn = max(scores)
best_params = {'n_neighbors': params['n_neighbors'][np.argmax(scores)]}
print("best score knn: ", best_score_knn)
print("best params", best_params)
# Out:
# best score knn:  0.49206349206349204
# best params {'n_neighbors': 1}

# %%
n_estimators_range = np.arange(1,121)
accuracy_scores = []
for n_estimators in n_estimators_range:
    rf = RandomForestClassifier(n_estimators=n_estimators)
    rf.fit(x_train, y_train)
    accuracy = rf.score(x_test, y_test)
    accuracy_scores.append(accuracy)
best_accuracy = max(accuracy_scores)
best_n_estimators = n_estimators_range[np.argmax(accuracy_scores)]
print("Best Accuracy rf:", best_accuracy)
print("Best n_estimators:", best_n_estimators)
# Out:
# Best Accuracy rf: 0.5555555555555556
# Best n_estimators: 69

# %%
kernel_types = ['linear', 'rbf', 'poly', 'sigmoid']
accuracy_scores = {}
for kernel_type in kernel_types:
    svc = SVC(kernel=kernel_type, C=1)
    svc.fit(x_train, y_train)
    accuracy_scores[kernel_type] = svc.score(x_test, y_test)
best_kernel = max(accuracy_scores, key=lambda k: accuracy_scores[k])
best_score = accuracy_scores[best_kernel]
print("Best Kernel:", best_kernel)
print("Best Score:", best_score)
# Out:
# Best Kernel: poly
# Best Score: 0.5714285714285714

# %%
C_values = np.arange(1, 20)
accuracy_scores = {}
for C_value in C_values:
    lr = LogisticRegression(C=C_value)
    lr.fit(x_train, y_train)
    accuracy_scores[C_value] = lr.score(x_test, y_test)
best_C = max(accuracy_scores, key=lambda k: accuracy_scores[k])
best_score_lr = accuracy_scores[best_C]
print("Best C:", best_C)
print("Best Score:", best_score_lr)
# Out:
# Best C: 1
# Best Score: 0.5682539682539682

# %% [markdown]
# # Visualising_Data_Of_Each_Prediction_Of_Classifiers

# %%
y_predicted = knc.predict(x_test)
cm = confusion_matrix(y_test, y_predicted)
sns.heatmap(cm, annot=True, cmap='YlGnBu')
plt.xlabel('Predict')
plt.ylabel('Truth')
plt.show()

# %%
y_predict = rf.predict(x_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True, cmap = 'YlGnBu')
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show()

# %%
y_predict = svc.predict(x_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True)
plt.xlabel('Prediction')
plt.ylabel('Truth')
plt.show()

# %%
y_predict = lr.predict(x_test)
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True)
plt.show()

# %% [markdown]
# # Price_Prediction

# %%
df_stocks = df[['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Tomorrow']]
df_stocks
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-05-23    37.422501    37.422501    36.227501    36.830002
# 1     2019-05-24    37.020000    37.375000    36.220001    36.287498
# 2     2019-05-28    36.465000    36.794998    35.812500    35.832500
# 3     2019-05-29    35.352501    35.705002    34.735001    35.084999
# 4     2019-05-30    35.077499    35.437500    34.392502    34.777500
# ...          ...          ...          ...          ...          ...
# 1255  2024-05-17   943.690002   947.400024   918.059998   924.789978
# 1256  2024-05-20   937.500000   952.000000   934.400024   947.799988
# 1257  2024-05-21   935.989990   954.000000   931.799988   953.859985
# 1258  2024-05-22   954.590027   960.200012   932.489990   949.500000
# 1259  2024-05-23  1020.000000  1063.199951  1015.200012  1058.918579
#
#         Adj Close    Volume     Tomorrow
# 0       36.579872  59184400    36.287498
# 1       36.041054  35758400    35.832500
# 2       35.589134  42835600    35.084999
# 3       34.846722  55980000    34.777500
# 4       34.580738  39430000    33.865002
# ...           ...       ...          ...
# 1255   924.789978  35969100   947.799988
# 1256   947.799988  31876400   953.859985
# 1257   953.859985  32894600   949.500000
# 1258   949.500000  53725900  1058.918579
# 1259  1058.918579  53658481          NaN
#
# [1260 rows x 8 columns]

# %%
df_stock = df_stocks.dropna()
y = df_stock['Tomorrow']
x = df_stock[['Open', 'High', 'Low', 'Close','Adj Close', 'Volume']]
df_stock
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2019-05-23   37.422501   37.422501   36.227501   36.830002   36.579872
# 1     2019-05-24   37.020000   37.375000   36.220001   36.287498   36.041054
# 2     2019-05-28   36.465000   36.794998   35.812500   35.832500   35.589134
# 3     2019-05-29   35.352501   35.705002   34.735001   35.084999   34.846722
# 4     2019-05-30   35.077499   35.437500   34.392502   34.777500   34.580738
# ...          ...         ...         ...         ...         ...         ...
# 1254  2024-05-16  949.099976  958.190002  941.030029  943.590027  943.590027
# 1255  2024-05-17  943.690002  947.400024  918.059998  924.789978  924.789978
# 1256  2024-05-20  937.500000  952.000000  934.400024  947.799988  947.799988
# 1257  2024-05-21  935.989990  954.000000  931.799988  953.859985  953.859985
# 1258  2024-05-22  954.590027  960.200012  932.489990  949.500000  949.500000
#
#         Volume     Tomorrow
# 0     59184400    36.287498
# 1     35758400    35.832500
# 2     42835600    35.084999
# 3     55980000    34.777500
# 4     39430000    33.865002
# ...        ...          ...
# 1254  32395200   924.789978
# 1255  35969100   947.799988
# 1256  31876400   953.859985
# 1257  32894600   949.500000
# 1258  53725900  1058.918579
#
# [1259 rows x 8 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
l_score = []

# %%
n_estimators_range = np.arange(1,121)
accuracy_scores = []
for n_estimators in n_estimators_range:
    rf = RandomForestRegressor(n_estimators=n_estimators)
    rf.fit(x_train, y_train)
    accuracy = rf.score(x_test, y_test)
    accuracy_scores.append(accuracy)
best_rf_accuracy = max(accuracy_scores)
best_n_estimators = n_estimators_range[np.argmax(accuracy_scores)]

# %%
lnr = LinearRegression()
lnr.fit(x_train,y_train)
lnr_score = lnr.score(x_test, y_test)

# %%
xr = XGBRegressor()
xr.fit(x_train, y_train)
xr_score = xr.score(x_test, y_test)

# %%
max_score = max(xr_score, lnr_score, best_rf_accuracy)
if max_score == xr_score:
    print("Model with Maximum Score: XGBoost Regressor")
    print("Maximum Score:", max_score)
elif max_score == lnr_score:
    print("Model with Maximum Score: Linear Regression")
    print("Maximum Score:", max_score)
else:
    print("Model with Maximum Score: Random Forest Regressor")
    print("Maximum Score:", max_score)
    print("Best n_estimators for Random Forest Regressor:", best_rf_n_estimators)
# Out:
# Model with Maximum Score: Linear Regression
# Maximum Score: 0.9965700741997597

# %% [markdown]
# # Predict_Any_Value

# %%
#max_score = max(xr_score, lnr_score, best_rf_accuracy)
#if max_score == xr_score:
#    NA_value = xr.predict([[]])
#elif max_score == lnr_score:
#    NA_value = lnr.predict([[]])
#else:
#    NA_value = rf.predict([[]])
#print(NA_value)

# %% [markdown]
# # Predicting_The_Last_NA_Value

# %%
max_score = max(xr_score, lnr_score, best_rf_accuracy)
if max_score == xr_score:
    NA_value = xr.predict([[1020.000000,1063.199951,1015.200012,1058.918579,1058.918579,53658481]])
elif max_score == lnr_score:
    NA_value = lnr.predict([[1020.000000,1063.199951,1015.200012,1058.918579,1058.918579,53658481]])
else:
    NA_value = rf.predict([[1020.000000,1063.199951,1015.200012,1058.918579,1058.918579,53658481]])
print(NA_value)
# Out:
# [1062.06805843]
