# %%
import random
import datetime
import csv

def generate_february_spending(seed=42):
    random.seed(seed)
    start_date = datetime.date(2025, 2, 1)
    spending_data = []

    for day in range(28):
        current_date = start_date + datetime.timedelta(days=day)
        if random.random() < 0.2:
            spending_data.append({
                "date": current_date.strftime("%Y-%m-%d"),
                "time": "00:00:00",
                "price": 0.00
            })
            continue  
        num_transactions = random.randint(1, 5)
        for _ in range(num_transactions):
            hour = random.randint(8, 22)
            minute = random.randint(0, 59)
            second = random.randint(0, 59)
            transaction_time = datetime.time(hour, minute, second)
            price = round(random.uniform(0.01, 100.00), 2)
            spending_data.append({
                "date": current_date.strftime("%Y-%m-%d"),
                "time": transaction_time.strftime("%H:%M:%S"),
                "price": price
            })

    return spending_data

february_data = generate_february_spending()

with open('spending.csv', 'w', newline='') as csvfile:
    fieldnames = ['date', 'time', 'price']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(february_data)

print("Data saved to february_spending.csv")
# Out:
# Data saved to february_spending.csv

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow import keras
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential
from keras.regularizers import l1_l2, l2
from keras.optimizers import Adam
from keras.initializers import HeNormal
from keras.callbacks import EarlyStopping

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_csv('spending.csv')
df.head()
# Out:
#          date      time  price
# 0  2025-02-01  19:17:15  22.33
# 1  2025-02-02  09:37:27   3.19
# 2  2025-02-02  09:13:14  50.54
# 3  2025-02-02  08:35:12  71.60
# 4  2025-02-02  19:34:26  22.05

# %%
df = df.groupby('date').agg({
    'price': 'sum'
}).rename(columns={'price': 'total_price'})
df.reset_index(inplace=True)

# %%
def extract_date_features(df, date_col):
    df[date_col] = pd.to_datetime(df[date_col])
    df['month'] = df[date_col].dt.month
    df['day_of_week'] = df[date_col].dt.dayofweek
    df['day_sin'] = np.sin(2 * np.pi * df['day_of_week'] / 7)
    df['day_cos'] = np.cos(2 * np.pi * df['day_of_week'] / 7)
    df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
    df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)
    
    return df
df = extract_date_features(df, 'date')

# %%
for i in range(1, 8):
    df[f'lag_{i}'] = df['total_price'].shift(i)

# %%
df.dropna(inplace=True)

# %%
df.sort_values('date', inplace=True)
df.set_index('date', inplace=True)

# %%
x = df.drop(columns=['total_price'])
y = df['total_price']

# %%
scale_x = MinMaxScaler()
scale_y = MinMaxScaler()
x_scaled = scale_x.fit_transform(x)
y_scaled = scale_y.fit_transform(y.values.reshape(-1,1))

# %%
def create_sequences(X, y, lookback):
    Xs, ys = [], []
    for i in range(len(X) - lookback):
        Xs.append(X[i:(i + lookback)])
        ys.append(y[i + lookback])
    return np.array(Xs), np.array(ys)
lookback = 7
x_seq, y_seq = create_sequences(x_scaled, y_scaled, lookback)

# %%
model = Sequential()
model.add(LSTM(units=24, activation='tanh', kernel_initializer=HeNormal(), kernel_regularizer=l1_l2(l1=0.01, l2=0.001), input_shape=(x_seq.shape[1], x_seq.shape[2]), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=12, activation='tanh', kernel_initializer=HeNormal(), kernel_regularizer=l1_l2(l1=0.01, l2=0.001), return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(units=1))
optimizer = Adam(learning_rate=0.005)


model.compile(optimizer=optimizer, loss='mse')
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_seq, y_seq, epochs=200, batch_size=16, validation_split=0.2, callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 10s 10s/step - loss: 7.8051 - val_loss: 7.3214
# Epoch 2/200
# 1/1 [==============================] - 0s 93ms/step - loss: 7.4744 - val_loss: 7.1228
# Epoch 3/200
# 1/1 [==============================] - 0s 95ms/step - loss: 7.2873 - val_loss: 6.9865
# Epoch 4/200
# 1/1 [==============================] - 0s 95ms/step - loss: 7.0397 - val_loss: 6.8862
# Epoch 5/200
# 1/1 [==============================] - 0s 93ms/step - loss: 6.9270 - val_loss: 6.8005
# Epoch 6/200
# 1/1 [==============================] - 0s 101ms/step - loss: 6.9862 - val_loss: 6.7188
# Epoch 7/200
# 1/1 [==============================] - 0s 108ms/step - loss: 6.8210 - val_loss: 6.6322
# Epoch 8/200
# 1/1 [==============================] - 0s 112ms/step - loss: 6.8578 - val_loss: 6.5393
# Epoch 9/200
# 1/1 [==============================] - 0s 102ms/step - loss: 6.6728 - val_loss: 6.4412
# Epoch 10/200
# 1/1 [==============================] - 0s 96ms/step - loss: 6.6057 - val_loss: 6.3390
# Epoch 11/200
# 1/1 [==============================] - 0s 90ms/step - loss: 6.4391 - val_loss: 6.2372
# Epoch 12/200
# 1/1 [==============================] - 0s 111ms/step - loss: 6.3441 - val_loss: 6.1370
# Epoch 13/200
# 1/1 [==============================] - 0s 97ms/step - loss: 6.2488 - val_loss: 6.0403
# Epoch 14/200
# 1/1 [==============================] - 0s 88ms/step - loss: 6.0791 - val_loss: 5.9473
# Epoch 15/200
# 1/1 [==============================] - 0s 87ms/step - loss: 6.0526 - val_loss: 5.8582
# Epoch 16/200
# 1/1 [==============================] - 0s 119ms/step - loss: 5.9753 - val_loss: 5.7724
# Epoch 17/200
# 1/1 [==============================] - 0s 100ms/step - loss: 5.7997 - val_loss: 5.6883
# Epoch 18/200
# 1/1 [==============================] - 0s 92ms/step - loss: 5.7384 - val_loss: 5.6041
# Epoch 19/200
# 1/1 [==============================] - 0s 96ms/step - loss: 5.7105 - val_loss: 5.5201
# Epoch 20/200
# 1/1 [==============================] - 0s 107ms/step - loss: 5.6399 - val_loss: 5.4352
# Epoch 21/200
# 1/1 [==============================] - 0s 100ms/step - loss: 5.5012 - val_loss: 5.3490
# Epoch 22/200
# 1/1 [==============================] - 0s 104ms/step - loss: 5.4099 - val_loss: 5.2623
# Epoch 23/200
# 1/1 [==============================] - 0s 90ms/step - loss: 5.3539 - val_loss: 5.1764
# Epoch 24/200
# 1/1 [==============================] - 0s 89ms/step - loss: 5.2012 - val_loss: 5.0904
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1973 - val_loss: 0.3356
# Epoch 168/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.2372 - val_loss: 0.2964
# Epoch 169/200
# 1/1 [==============================] - 0s 100ms/step - loss: 0.1888 - val_loss: 0.2480
# Epoch 170/200
# 1/1 [==============================] - 0s 95ms/step - loss: 0.2046 - val_loss: 0.2326
# Epoch 171/200
# 1/1 [==============================] - 0s 94ms/step - loss: 0.2101 - val_loss: 0.2549
# Epoch 172/200
# 1/1 [==============================] - 0s 90ms/step - loss: 0.1757 - val_loss: 0.2801
# Epoch 173/200
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1853 - val_loss: 0.2839
# Epoch 174/200
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1884 - val_loss: 0.2518
# Epoch 175/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1642 - val_loss: 0.2272
# Epoch 176/200
# 1/1 [==============================] - 0s 105ms/step - loss: 0.1703 - val_loss: 0.2217
# Epoch 177/200
# 1/1 [==============================] - 0s 94ms/step - loss: 0.1790 - val_loss: 0.2304
# Epoch 178/200
# 1/1 [==============================] - 0s 95ms/step - loss: 0.1572 - val_loss: 0.2379
# Epoch 179/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1660 - val_loss: 0.2560
# Epoch 180/200
# 1/1 [==============================] - 0s 86ms/step - loss: 0.1694 - val_loss: 0.2559
# Epoch 181/200
# 1/1 [==============================] - 0s 87ms/step - loss: 0.1754 - val_loss: 0.2366
# Epoch 182/200
# 1/1 [==============================] - 0s 89ms/step - loss: 0.1457 - val_loss: 0.2233
# Epoch 183/200
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1502 - val_loss: 0.2280
# Epoch 184/200
# 1/1 [==============================] - 0s 92ms/step - loss: 0.1577 - val_loss: 0.2399
# Epoch 185/200
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1435 - val_loss: 0.2315
# Epoch 186/200
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1475 - val_loss: 0.2157
# Epoch 187/200
# 1/1 [==============================] - 0s 110ms/step - loss: 0.1392 - val_loss: 0.2039
# Epoch 188/200
# 1/1 [==============================] - 0s 118ms/step - loss: 0.1632 - val_loss: 0.2031
# Epoch 189/200
# 1/1 [==============================] - 0s 105ms/step - loss: 0.1345 - val_loss: 0.2047
# Epoch 190/200
# 1/1 [==============================] - 0s 102ms/step - loss: 0.1516 - val_loss: 0.2148
# Epoch 191/200
# 1/1 [==============================] - 0s 107ms/step - loss: 0.1384 - val_loss: 0.2194
# Epoch 192/200
# 1/1 [==============================] - 0s 103ms/step - loss: 0.1443 - val_loss: 0.2142
# Epoch 193/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1216 - val_loss: 0.2108
# Epoch 194/200
# 1/1 [==============================] - 0s 91ms/step - loss: 0.1263 - val_loss: 0.2066
# Epoch 195/200
# 1/1 [==============================] - 0s 94ms/step - loss: 0.1171 - val_loss: 0.2044
# Epoch 196/200
# 1/1 [==============================] - 0s 99ms/step - loss: 0.1178 - val_loss: 0.2007
# Epoch 197/200
# 1/1 [==============================] - 0s 108ms/step - loss: 0.1360 - val_loss: 0.1951
# Epoch 198/200
# 1/1 [==============================] - 0s 106ms/step - loss: 0.1412 - val_loss: 0.1885
# Epoch 199/200
# 1/1 [==============================] - 0s 234ms/step - loss: 0.1234 - val_loss: 0.1805
# Epoch 200/200
# 1/1 [==============================] - 0s 259ms/step - loss: 0.1231 - val_loss: 0.1885

# %%
x_train, x_test, y_train, y_test = train_test_split(x_seq, y_seq, test_size=0.2)

# %%
y_pred_scaled = model.predict(x_test)
y_pred = scale_y.inverse_transform(y_pred_scaled)  # Inverse transform to get original scale
y_test_original = scale_y.inverse_transform(y_test)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
mae = mean_absolute_error(y_test_original, y_pred)
rmse = np.sqrt(mean_squared_error(y_test_original, y_pred))
print(f'MAE: {mae:.2f}, RMSE: {rmse:.2f}')
# Out:
# MAE: 38.24, RMSE: 42.11

# %%
x.columns
# Out:
# Index(['month', 'day_of_week', 'day_sin', 'day_cos', 'month_sin', 'month_cos',
#        'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7'],
#       dtype='object')

# %%
df_test[]
